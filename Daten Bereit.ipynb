# %%
import os
print("=== EFT-Lapse Modus-D: Sachs-Wolfe Test ===")

# Dateien prüfen
files = os.listdir('.')
data_files = [f for f in files if any(f.endswith(x) for x in ['.fits', '.npy', '.txt', '.dat'])]
for f in data_files:
    size = os.path.getsize(f) / 1e6
    print(f"{size:6.1f} MB  {f}")

print("\n✓ Daten bereit für ISW-Stacking!")
# Out:
# === EFT-Lapse Modus-D: Sachs-Wolfe Test ===
# 2013.3 MB  COM_CMB_IQU-smica_2048_R3.00_full.fits
#    0.0 MB  COM_CMB_IQU-smica_2048_R3.00_full.fits.header.txt
#  116.1 MB  cosmicflows_2mpp.txt
#  165.7 MB  planck_smica_cmb.fits
#  135.8 MB  twompp_density.npy
#    0.0 MB  twompp_README.txt
#  407.4 MB  twompp_velocity.npy
#    3.2 MB  VoidFinder-nsa_v1_0_1_Planck2018_comoving_holes.txt
#
# ✓ Daten bereit für ISW-Stacking!
